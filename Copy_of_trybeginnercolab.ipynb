# %% [markdown]
# <a href="https://colab.research.google.com/github/cklai6288/gitHubTest/blob/main/Copy_of_trybeginnercolab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.ndarray

# %%
x = 1
y = 4
z = y/(1-x)

# %%
import pandas as pd
mylist = [2, 3, 4]
res = pd.Series(mylist)
print("Series", res)
# Out:
# Series 0    2
# 1    3
# 2    4
# dtype: int64

# %%
import numpy as np
arr = np.array((2,3,4))
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpt = np.array([2,3])
ypt = np.array([23,9])
plt.plot(xpt,ypt)
plt.show()
